# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import scipy.stats as ss
from util import Util
np.set_printoptions(precision=2, suppress = True, linewidth = 100)

# %% [markdown]
# ## Part 1: Loading and examining the dataset

# %%
filepaths = ["data/simple1.txt", 
             "data/simple2.txt", 
             "data/test.txt", 
             "data/toy.txt", 
             "data/train_full.txt", 
             "data/train_noisy.txt", 
             "data/train_sub.txt", 
             "data/validation.txt",
             "data/sample_biased.txt"]
Util.read_and_analyze(filepaths)
# Out:
# simple1.txt :
# load 1266 data instances, each having 4 features
# There are 2 unique label(s) with the following numbers and distribution
# {'A': 667, 'C': 599}
# {'A': '53%', 'C': '47%'}
# The labels are balanced
# Average feature value for each char
# A [2.02 8.5  7.8  3.61]
# C [ 7.11 11.93  8.8   7.61]
# Standard error of features for each char
# A [1.26 1.24 1.72 1.87]
# C [1.91 1.75 2.17 0.94]
# Max and min feature value for the feature
# max: [12 15 13 10]
# min: [0 5 3 0]
#
# simple2.txt :
# load 2596 data instances, each having 7 features
# There are 4 unique label(s) with the following numbers and distribution
# {'A': 667, 'C': 599, 'E': 659, 'G': 671}
# {'A': '26%', 'C': '23%', 'E': '25%', 'G': '26%'}
# The labels are balanced
# Average feature value for each char
# A [2.02 8.5  7.8  3.61 3.36 2.97 2.84]
# C [ 7.11 11.93  8.8   7.61  4.09  2.84  4.09]
# E [ 7.64 10.35  8.5   7.34  3.72  3.68  6.01]
# G [5.34 9.59 7.41 6.56 4.08 3.55 5.14]
# Standard error of features for each char
# A [1.26 1.24 1.72 1.87 1.54 1.75 1.58]
# C [1.91 1.75 2.17 0.94 1.81 1.73 1.54]
# E [2.12 2.28 2.   0.86 1.55 1.9  1.48]
# G [1.78 1.58 1.67 1.07 1.73 2.06 1.48]
# Max and min feature value for the feature
# max: [12 15 13 10 10 12 11]
# min: [0 4 3 0 0 0 0]
#
# test.txt :
# load 200 data instances, each having 16 features
# There are 6 unique label(s) with the following numbers and distribution
# {'A': 34, 'C': 37, 'E': 26, 'G': 27, 'O': 34, 'Q': 42}
# {'A': '17%', 'C': '18%', 'E': '13%', 'G': '14%', 'O': '17%', 'Q': '21%'}
# The labels are unbalanced towards
# ['E' 'Q']
# Average feature value for each char
# A [3.26 7.56 5.09 5.38 3.24 9.24 3.79 3.21 2.38 8.   2.62 8.41 3.03 6.38 3.21 7.5 ]
# C [ 4.14  7.38  4.59  5.62  2.35  5.59  7.81  6.16  7.92  8.76  7.35 12.03  1.46  8.68  4.11  8.76]
# E [ 3.85  7.35  4.85  5.69  3.73  5.38  7.62  4.15  7.92  8.69  6.35 10.92  2.08  8.23  5.88  8.08]
# G [4.33 7.22 5.19 5.44 3.85 7.52 6.67 5.85 5.11 7.67 5.93 9.48 3.22 8.33 5.3  9.52]
# O [3.91 6.44 4.91 5.06 3.76 7.56 6.82 6.74 4.29 8.12 5.74 8.26 3.65 8.12 3.74 7.88]
# Q [4.38 7.19 5.21 6.86 4.29 8.26 6.9  6.33 4.43 6.98 6.4  9.24 3.29 8.43 5.57 8.98]
# Standard error of features for each char
# A [1.31 3.3  1.48 2.14 1.65 2.02 1.78 1.59 1.21 1.85 1.96 1.37 1.5  1.19 1.75 1.7 ]
# C [1.93 3.98 1.55 2.39 1.58 1.2  1.16 1.15 1.88 2.49 1.56 1.6  1.2  1.16 1.35 1.3 ]
# E [1.1  2.63 1.49 1.77 1.87 2.15 0.84 1.61 2.53 2.01 1.33 2.64 1.8  0.58 1.55 1.75]
# G [1.59 3.08 1.42 1.87 2.22 1.13 1.56 1.27 2.27 1.92 1.27 1.29 2.06 1.19 1.56 1.37]
# O [1.6  3.26 1.77 2.2  2.29 0.81 1.1  1.34 1.54 1.21 1.22 0.98 2.17 1.16 1.15 1.28]
# Q [1.75 3.33 1.67 2.18 2.19 0.82 2.15 1.64 2.07 1.98 1.66 1.15 1.48 1.47 1.79 1.71]
# Max and min feature value for the feature
# max: [ 9 15  9 11 11 13 11  9 12 13 11 15 11 14 10 15]
# min: [1 0 1 0 0 2 1 1 0 5 0 5 0 3 1 4]
#
# toy.txt :
# load 10 data instances, each having 3 features
# There are 2 unique label(s) with the following numbers and distribution
# {'A': 5, 'C': 5}
# {'A': '50%', 'C': '50%'}
# The labels are balanced
# Average feature value for each char
# A [2.8 6.  2.8]
# C [2.2 3.  2.2]
# Standard error of features for each char
# A [1.94 0.63 1.33]
# C [1.47 1.41 2.04]
# Max and min feature value for the feature
# max: [5 7 6]
# min: [0 1 0]
#
# train_full.txt :
# load 3900 data instances, each having 16 features
# There are 6 unique label(s) with the following numbers and distribution
# {'A': 667, 'C': 599, 'E': 659, 'G': 671, 'O': 637, 'Q': 667}
# {'A': '17%', 'C': '15%', 'E': '17%', 'G': '17%', 'O': '16%', 'Q': '17%'}
# The labels are slightly unbalanced
# Average feature value for each char
# A [3.36 6.98 5.13 5.18 2.97 8.85 3.61 2.7  2.02 7.8  2.35 8.5  2.77 6.3  2.84 7.5 ]
# C [ 4.09  7.13  4.76  5.33  2.84  5.4   7.61  5.89  7.11  8.8   7.53 11.93  2.05  8.88  4.09  8.53]
# E [ 3.72  6.95  4.75  5.2   3.68  5.94  7.34  4.24  7.64  8.5   6.26 10.35  2.11  8.29  6.01  8.48]
# G [4.08 6.97 4.97 5.27 3.55 6.87 6.56 5.96 5.34 7.41 6.14 9.59 2.81 8.35 5.14 9.23]
# O [4.14 7.14 4.88 5.33 3.48 7.33 6.96 7.14 4.82 7.92 5.86 8.03 3.36 8.1  3.64 7.86]
# Q [4.02 6.36 4.89 6.36 4.12 8.14 6.8  6.05 3.86 6.81 6.35 9.24 3.12 8.31 5.34 8.91]
# Standard error of features for each char
# A [1.54 3.36 1.55 2.15 1.75 1.93 1.87 1.24 1.26 1.72 1.89 1.24 1.36 1.25 1.58 1.43]
# C [1.81 3.3  1.58 2.14 1.73 1.18 0.94 1.36 1.91 2.17 1.49 1.75 1.64 0.98 1.54 1.38]
# E [1.55 3.17 1.8  2.11 1.9  1.92 0.86 1.64 2.12 2.   1.2  2.28 1.65 0.76 1.48 1.54]
# G [1.73 3.37 1.66 2.2  2.06 0.99 1.07 1.17 1.78 1.67 1.06 1.58 1.81 1.07 1.48 1.37]
# O [1.76 3.32 1.66 2.21 1.9  0.78 0.96 1.28 1.52 1.29 1.15 1.07 1.64 0.68 1.08 0.9 ]
# Q [1.73 3.24 1.76 2.55 2.09 0.96 1.82 1.46 1.91 1.89 1.64 1.2  1.17 1.47 1.56 1.49]
# Max and min feature value for the feature
# max: [10 15 11 12 14 14 14 10 12 13 11 15 12 15 11 14]
# min: [0 0 1 0 0 2 0 0 0 3 0 4 0 1 0 1]
#
# train_noisy.txt :
# load 3900 data instances, each having 16 features
# There are 6 unique label(s) with the following numbers and distribution
# {'A': 681, 'C': 571, 'E': 678, 'G': 622, 'O': 666, 'Q': 682}
# {'A': '17%', 'C': '15%', 'E': '17%', 'G': '16%', 'O': '17%', 'Q': '17%'}
# The labels are balanced
# Average feature value for each char
# A [3.43 7.03 5.18 5.21 3.04 8.87 3.59 2.72 2.05 7.85 2.36 8.56 2.81 6.31 2.89 7.52]
# C [ 4.    6.95  4.61  5.22  2.64  5.22  7.64  5.91  7.23  8.84  7.57 12.1   1.89  8.83  3.81  8.44]
# E [ 3.76  7.08  4.8   5.28  3.74  5.88  7.33  4.15  7.7   8.48  6.2  10.28  2.14  8.23  6.11  8.39]
# G [4.2  7.23 5.21 5.36 3.81 6.86 6.57 5.91 5.28 7.44 6.24 9.67 2.98 8.51 5.37 9.45]
# O [4.14 7.16 4.85 5.31 3.4  7.4  7.   7.25 4.92 7.94 5.86 8.03 3.32 8.11 3.61 7.86]
# Q [3.89 6.08 4.73 6.27 3.97 8.15 6.83 6.09 3.77 6.7  6.4  9.22 3.02 8.33 5.29 8.93]
# Standard error of features for each char
# A [1.59 3.34 1.58 2.15 1.8  1.89 1.8  1.16 1.28 1.71 1.82 1.27 1.37 1.25 1.58 1.36]
# C [1.8  3.32 1.52 2.18 1.52 1.03 0.92 1.2  1.78 2.07 1.48 1.64 1.55 0.98 1.03 1.25]
# E [1.56 3.23 1.81 2.14 1.94 1.89 0.95 1.6  2.   2.02 1.26 2.33 1.61 0.87 1.57 1.57]
# G [1.73 3.13 1.68 2.07 2.13 0.86 1.07 1.26 1.8  1.72 1.1  1.29 1.84 1.17 1.68 1.41]
# O [1.82 3.4  1.7  2.26 1.88 0.74 0.97 1.14 1.54 1.53 1.1  1.17 1.64 0.77 1.06 0.84]
# Q [1.65 3.26 1.65 2.58 2.08 0.91 1.72 1.45 1.86 1.69 1.59 1.29 1.26 1.29 1.39 1.52]
# Max and min feature value for the feature
# max: [10 15 11 12 14 14 14 10 12 13 11 15 12 15 11 14]
# min: [0 0 1 0 0 2 0 0 0 3 0 4 0 1 0 1]
#
# train_sub.txt :
# load 600 data instances, each having 16 features
# There are 6 unique label(s) with the following numbers and distribution
# {'A': 94, 'C': 187, 'E': 129, 'G': 21, 'O': 113, 'Q': 56}
# {'A': '16%', 'C': '31%', 'E': '22%', 'G': '4%', 'O': '19%', 'Q': '9%'}
# The labels are unbalanced towards
# ['C' 'E' 'G' 'Q']
# Average feature value for each char
# A [3.35 7.43 5.22 5.41 2.89 9.15 3.65 2.66 2.05 7.97 2.2  8.56 2.74 6.3  2.76 7.52]
# C [ 4.14  6.98  4.75  5.34  2.84  5.39  7.68  5.91  7.11  8.96  7.55 12.05  1.97  8.96  4.1   8.53]
# E [ 3.72  6.56  4.71  5.    3.51  5.75  7.45  4.23  7.66  8.66  6.5  10.26  2.02  8.33  5.81  8.22]
# G [4.29 6.95 5.24 5.29 3.52 6.81 6.14 6.   5.38 6.86 5.71 9.43 2.67 8.19 5.14 9.14]
# O [4.06 7.08 4.77 5.38 3.19 7.35 6.95 7.27 5.09 7.86 5.89 8.   3.15 8.02 3.65 7.8 ]
# Q [4.09 6.71 4.89 6.61 4.21 8.12 6.82 5.93 3.66 7.11 6.29 9.48 3.11 8.41 5.3  8.61]
# Standard error of features for each char
# A [1.53 3.29 1.52 2.02 1.65 1.98 1.73 0.97 1.18 1.72 1.78 1.13 1.38 1.3  1.37 1.49]
# C [1.96 3.61 1.7  2.25 1.64 1.14 0.9  1.37 1.78 2.15 1.51 1.72 1.49 0.94 1.45 1.39]
# E [1.65 3.26 1.88 2.15 1.83 1.85 0.84 1.56 2.16 2.01 1.35 2.33 1.48 0.77 1.45 1.62]
# G [2.43 4.19 2.22 2.83 2.4  0.96 1.08 1.15 1.79 1.42 1.08 1.84 1.64 0.91 1.46 1.55]
# O [1.7  3.3  1.59 2.22 1.54 0.8  0.9  1.21 1.53 1.22 1.08 1.23 1.18 0.7  0.96 0.83]
# Q [1.77 3.08 1.65 2.56 2.06 0.87 1.83 1.44 2.06 1.77 1.69 1.22 0.99 1.53 1.55 1.29]
# Max and min feature value for the feature
# max: [10 15 10 11 11 14 12 10 12 13 11 15  9 15 10 13]
# min: [0 0 1 0 0 2 0 1 0 3 0 4 0 2 1 1]
#
# validation.txt :
# load 100 data instances, each having 16 features
# There are 6 unique label(s) with the following numbers and distribution
# {'A': 19, 'C': 13, 'E': 18, 'G': 14, 'O': 20, 'Q': 16}
# {'A': '19%', 'C': '13%', 'E': '18%', 'G': '14%', 'O': '20%', 'Q': '16%'}
# The labels are unbalanced towards
# ['C' 'O']
# Average feature value for each char
# A [3.58 6.79 5.32 5.16 3.26 8.79 3.58 3.   2.   7.84 2.16 8.47 2.63 6.21 3.21 7.37]
# C [ 3.85  5.85  4.31  4.38  2.    5.23  7.92  6.08  8.08  9.15  7.54 12.38  1.08  8.77  3.69  8.46]
# E [ 4.33  7.89  5.06  6.    3.72  5.94  7.67  4.83  7.56  8.22  6.33 10.72  1.94  8.17  6.5   8.33]
# G [4.43 7.93 5.21 5.5  4.   6.71 7.   5.79 5.   7.79 6.57 9.5  3.36 8.64 5.43 8.64]
# O [4.1  7.5  5.05 5.7  3.9  7.5  7.15 7.25 4.6  7.95 6.   7.55 3.55 7.9  3.55 8.  ]
# Q [3.25 5.25 4.06 5.62 3.31 8.25 6.88 6.38 3.75 6.56 6.31 8.88 2.56 8.56 4.19 8.94]
# Standard error of features for each char
# A [1.57 3.07 1.89 2.5  1.92 1.99 1.79 1.62 1.49 1.69 1.42 1.35 1.13 1.32 2.55 1.87]
# C [2.21 3.96 1.81 2.1  1.3  0.8  1.21 0.62 1.27 2.57 1.55 2.13 0.92 1.31 0.61 1.28]
# E [1.33 2.42 1.72 1.6  1.45 2.12 1.11 1.46 2.81 1.93 1.2  2.33 1.54 0.69 1.17 1.83]
# G [1.12 1.98 1.32 1.5  1.96 0.8  1.07 1.47 1.73 1.66 0.98 1.24 1.54 1.11 1.59 1.34]
# O [1.51 3.09 1.69 2.26 2.   0.59 0.91 1.18 1.74 1.16 1.1  1.02 1.72 0.62 0.8  0.89]
# Q [1.39 3.13 1.6  2.83 1.93 1.03 1.49 1.22 1.44 1.58 1.16 0.86 0.61 0.61 1.01 1.14]
# Max and min feature value for the feature
# max: [ 8 13  9 11  9 13 11  9 12 12 10 15  8 12 11 12]
# min: [1 0 1 1 0 3 0 1 0 4 0 5 0 3 1 3]
#
# sample_biased.txt :
# load 166 data instances, each having 3 features
# There are 2 unique label(s) with the following numbers and distribution
# {'A': 37, 'C': 129}
# {'A': '22%', 'C': '78%'}
# The labels are unbalanced towards
# ['A' 'C']
# Average feature value for each char
# A [0.49 5.49 4.03]
# C [2.2  2.99 2.2 ]
# Standard error of features for each char
# A [0.5 0.5 1. ]
# C [1.48 1.42 2.05]
# Max and min feature value for the feature
# max: [5 6 6]
# min: [0 1 0]
